# %%
import xarray as xr
import gcsfs
import numpy as np
from regridding import regrid

fs = gcsfs.GCSFileSystem(token="anon")

store = fs.get_mapper('gs://weatherbench2/datasets/era5/1959-2023_01_10-wb13-6h-1440x721_with_derived_variables.zarr')
ds = xr.open_zarr(store=store, consolidated=True)

df_era5 = ds.total_precipitation_6hr.sel({'time':np.arange('2018-01-01','2023-01-11',np.timedelta64(1,'D'),dtype='datetime64[ns]')})

lons_reg = ## give lon values e.g., for IMERG 0.1 degree grid: np.arange(19.15, 54.35, 0.1)
lats_reg = ## give lat values e.g., for IMERG 0.1 degree grid:  np.arange(-13.65, 24.75, 0.1)

df_era5['longitude'] = df_era5.longitude.values - 180

regridder = regrid(lons_reg, lats_reg, df_era5)

df_era5_regridded = regridder(df_era5, keep_attrs=True)

# %%
df_era5_regridded
# Out:
# <xarray.DataArray 'total_precipitation_6hr' (time: 1836, lat: 384, lon: 352)> Size: 993MB
# dask.array<astype, shape=(1836, 384, 352), dtype=float32, chunksize=(1, 384, 352), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 15kB 2018-01-01 2018-01-02 ... 2023-01-10
#   * lat      (lat) float64 3kB -13.65 -13.55 -13.45 -13.35 ... 24.45 24.55 24.65
#   * lon      (lon) float64 3kB 19.15 19.25 19.35 19.45 ... 54.05 54.15 54.25
# Attributes:
#     long_name:      Total precipitation
#     short_name:     tp
#     units:          m
#     regrid_method:  conservative

# %%
ds
# Out:
# <xarray.Dataset> Size: 89TB
# Dimensions:                                           (time: 93544,
#                                                        latitude: 721,
#                                                        longitude: 1440,
#                                                        level: 13)
# Coordinates:
#   * latitude                                          (latitude) float32 3kB ...
#   * level                                             (level) int64 104B 50 ....
#   * longitude                                         (longitude) float32 6kB ...
#   * time                                              (time) datetime64[ns] 748kB ...
# Data variables: (12/62)
#     10m_u_component_of_wind                           (time, latitude, longitude) float32 388GB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     10m_v_component_of_wind                           (time, latitude, longitude) float32 388GB dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# ...
